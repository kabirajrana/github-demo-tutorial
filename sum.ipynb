# %% [markdown]
# ### Ask user to input
# - This is a way of asking  user to input number that you want to sum of

# %%
num1 = int(input('Enter a number: '))
num2 = int(input('Enter second number: '))
sum = num1 + num2
print(f'The sum of two number is: {sum}')
